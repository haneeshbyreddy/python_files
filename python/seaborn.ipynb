# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\sriva\OneDrive\Desktop\data1.csv",sep=",")

# %%
print(df.shape)
df.info()
# Out:
# (150, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
res=sns.scatterplot(x='sepal.length', y='sepal.width',data=df)

# %%
res=sns.scatterplot(x='sepal.length', 
                y='sepal.width',data=df,hue="variety",palette="Set2")

# %%
df.corr()
top=df.head(20)

# %%
# importing the required library

import seaborn as sns
import matplotlib.pyplot as plt

# read a tips.csv file from seaborn library
print(top.head(20))

# count plot on single categorical variable
sns.countplot(x ='petal.length', data = top,hue='variety',palette='Set2')

# Show the plot
plt.show()
# Out:
#     sepal.length  sepal.width  petal.length  petal.width     variety
# 0            5.1          3.5           1.4          0.2      Setosa
# 1            4.9          3.0           1.4          0.2      Setosa
# 2            4.7          3.2           1.3          0.2      Setosa
# 3            4.6          3.1           1.5          0.2      Setosa
# 4            5.0          3.6           1.4          0.2      Setosa
# 5            5.4          3.9           1.7          0.4      Setosa
# 6            4.6          3.4           1.4          0.3  Versicolor
# 7            5.0          3.4           1.5          0.2  Versicolor
# 8            4.4          2.9           1.4          0.2  Versicolor
# 9            4.9          3.1           1.5          0.1  Versicolor
# 10           5.4          3.7           1.5          0.2   Virginica
# 11           4.8          3.4           1.6          0.2   Virginica
# 12           4.8          3.0           1.4          0.1   Virginica
# ...

# %%
# importing the required library
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="dark")
# read a titanic.csv file
# from seaborn library
df = sns.load_dataset('titanic')

sns.countplot(x = 'class',
			hue = 'sex', 
			data = df,palette='Set1')

# Show the plot
plt.show()

# %%
sns.set(style="white")
plt.show()

# %%
import seaborn as sns  
sns.set(style="white")  
  
# Load the example mpg dataset  
mpg = sns.load_dataset("mpg") 
print(mpg.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
sns.relplot(data=mpg,x="horsepower",y="mpg",hue='origin', alpha=.5, palette="magma",
            height=6)

# %%
sns.relplot(x="horsepower", y="mpg", hue="origin", size="weight",  
            sizes=(500, 40), alpha=.5, palette="muted",  
            height=6, data=mpg)

# %%
import seaborn as sns
import numpy as np
import matplotlib as plt
# %matplotlib inline
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y='tip',data=tip)
#here kind by default scatter and we change kind if we want

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='line',sort=False)

# %%
sns.relplot(x='total_bill',y='tip',data=tip,kind='line',sort=True)

# %%
#we can group the data by hue -->it will differentiate with color
sns.relplot(x='total_bill',y='tip',data=tip,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=tip,hue='day')

# %%
#by above group we group them by day in that if we want how many smoker and non smoker we use style
sns.relplot(x='total_bill',y='tip',data=tip,hue='day',style='smoker')

# %%
#and also we can know the size of that are group with day
sns.relplot(x='total_bill',y='tip',data=tip,hue='day',size='size')

# %%
sns.scatterplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#to know the relation between the  categorial and numerical data we use catplot
sns.catplot(x='day',y='tip',data=tip)

# %%
sns.catplot(x='day',y='tip',data=tip,kind='box',hue='sex')

# %%
sns.catplot(x='day',y='tip',data=tip,kind="box")

# %%
#to know the distribution
x=np.random.randn(10000000)

sns.displot(x)

# %%
#jointplot 2 or more we can see here we can see the scatter and distribution
sns.jointplot(x=tip['total_bill'],y=tip['tip'])

# %%
#to know the best fitted line
sns.lmplot(x='total_bill',y='tip',data=tip)

# %%
#same as lmplot but it will take some distribution
sns.regplot(x='total_bill',y='tip',data=tip)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x='total_bill',y='tip',data=tip,col='day')

# %%
#for every each pair relation
sns.pairplot(tip)

# %%
from scipy import constants
print(constants.liter)
# Out:
# 0.001

# %%
print(dir())
# Out:
# ['In', 'Out', '_', '_10', '_12', '_13', '_14', '_15', '_16', '_17', '_19', '_22', '_23', '_24', '_25', '_26', '_27', '_28', '_31', '_32', '_33', '_34', '_35', '_36', '_37', '_39', '_4', '_40', '_41', '_42', '_5', '_6', '_7', '_8', '_9', '__', '___', '__builtin__', '__builtins__', '__doc__', '__loader__', '__name__', '__package__', '__spec__', '__vsc_ipynb_file__', '_dh', '_i', '_i1', '_i10', '_i11', '_i12', '_i13', '_i14', '_i15', '_i16', '_i17', '_i18', '_i19', '_i2', '_i20', '_i21', '_i22', '_i23', '_i24', '_i25', '_i26', '_i27', '_i28', '_i29', '_i3', '_i30', '_i31', '_i32', '_i33', '_i34', '_i35', '_i36', '_i37', '_i38', '_i39', '_i4', '_i40', '_i41', '_i42', '_i43', '_i44', '_i45', '_i46', '_i47', '_i5', '_i6', '_i7', '_i8', '_i9', '_ih', '_ii', '_iii', '_oh', 'constants', 'exit', 'get_ipython', 'np', 'plt', 'quit', 'sns', 'tip', 'x']

# %%
from scipy.optimize import root
from math import cos

def eqn(x):
  return x + cos(x)

myroot = root(eqn,0.6)

print(myroot.x)
# Out:
# [-0.73908513]

# %%
import numpy as np
from scipy import signal
sig = np.repeat([0., 1., 0.], 100)
win = signal.windows.hann(50)
filtered = signal.convolve(sig, win, mode='same') / sum(win)

# %%
import matplotlib.pyplot as plt
fig, (ax_orig, ax_win, ax_filt) = plt.subplots(3, 1, sharex=True)
ax_orig.plot(sig)
ax_orig.set_title('Original pulse')
ax_orig.margins(0, 0.1)
ax_win.plot(win)
ax_win.set_title('Filter impulse response')
ax_win.margins(0, 0.1)
ax_filt.plot(filtered)
ax_filt.set_title('Filtered signal')
ax_filt.margins(0, 0.1)
fig.tight_layout()
fig.show()
# Out:
# C:\Users\sriva\AppData\Local\Temp/ipykernel_13032/1191760211.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
rng = np.random.default_rng()

# %%
sig = np.repeat([0., 1., 1., 0., 1., 0., 0., 1.], 128)
sig_noise = sig + rng.standard_normal(len(sig))
corr = signal.correlate(sig_noise, np.ones(128), mode='same') / 128
clock = np.arange(64, len(sig), 128)
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, sharex=True)
ax_orig.plot(sig)
ax_orig.plot(clock, sig[clock], 'ro')
ax_orig.set_title('Original signal')
ax_noise.plot(sig_noise)
ax_noise.set_title('Signal with noise')
ax_corr.plot(corr)
ax_corr.plot(clock, corr[clock], 'ro')
ax_corr.axhline(0.5, ls=':')
ax_corr.set_title('Cross-correlated with rectangular pulse')
ax_orig.margins(0, 0.1)
fig.tight_layout()
plt.show()

# %%
x = np.arange(128) / 128
sig = np.sin(2 * np.pi * x)
sig_noise = sig + rng.standard_normal(len(sig))
corr = signal.correlate(sig_noise, sig)
lags = signal.correlation_lags(len(sig), len(sig_noise))
corr /= np.max(corr)
fig, (ax_orig, ax_noise, ax_corr) = plt.subplots(3, 1, figsize=(4.8, 4.8))
ax_orig.plot(sig)
ax_orig.set_title('Original signal')
ax_orig.set_xlabel('Sample Number')
ax_noise.plot(sig_noise)
ax_noise.set_title('Signal with noise')
ax_noise.set_xlabel('Sample Number')
ax_corr.plot(lags, corr)
ax_corr.set_title('Cross-correlated signal')
ax_corr.set_xlabel('Lag')
ax_orig.margins(0, 0.1)
ax_noise.margins(0, 0.1)
ax_corr.margins(0, 0.1)
fig.tight_layout()
plt.show()

# %%
rng = np.random.default_rng()
